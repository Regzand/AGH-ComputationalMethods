# %%
from math import sqrt, sin
from operator import mul
from functools import reduce
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
def tabularize(f, domain, samples):
    return [(x, f(x)) for x in np.linspace(DOMAIN[0], DOMAIN[1], samples)]

# %% [markdown]
# ## Input data
# ---

# %%
def F1(x): return sqrt(x)
def F2(x): return sin(x)
def F3(x): return x**3 + 2*x

FUNCTIONS = [F1, F2, F3]
DOMAIN = (0, 10)
SAMPLES = [3,4,5,8]

# %% [markdown]
# #### Tabularized functions

# %%
tables = dict()

for f in FUNCTIONS:
    tables[f.__name__] = dict()
    for s in SAMPLES:
        tables[f.__name__][s] = tabularize(f, DOMAIN, s)

# %% [markdown]
# ## Lagrange polynomial
# ---

# %% [markdown]
# $$ w(x) = \sum_{i=0}^{n}{y_i \prod_{j=0 \land j \ne i}^{n}{\frac{x-x_j}{x_i-x_j}}} $$

# %%
def lagrange(samples):
    return lambda x: sum(
        samples[i][1] * reduce(mul,(
            (x - samples[j][0]) / (samples[i][0] - samples[j][0])
            for j in range(len(samples))
            if j != i
        ), 1)
        for i in range(len(samples))
    )

# %% [markdown]
# ## Graphs
# ---

# %%
x = np.linspace(DOMAIN[0], DOMAIN[1], 100)

for f in FUNCTIONS:
    for s in SAMPLES:
        plt.figure()
        plt.title(f'Function {f.__name__} - {s} samples')
        # tabularized points
        plt.plot(*zip(*tables[f.__name__][s]), 'ro')
        # input function
        plt.plot(x, list(map(f, x)), 'r--')
        # interpolated function
        plt.plot(x, list(map(lagrange(tables[f.__name__][s]), x)), 'c')

# %% [markdown]
# ## Errors
# ---

# %%
for f in FUNCTIONS:
    for s in SAMPLES:
        print(f'\n> Function {f.__name__} - {s} samples')
        L = lagrange(tables[f.__name__][s])
        for x in np.linspace(DOMAIN[0], DOMAIN[1], 2*s-1):
            print("\t x = %10f \t error = %+10f \t relative = %5.2f%%" % (x, (L(x)-f(x)), abs(L(x)-f(x))/f(x)*100 if f(x) != 0 else 0))
# Out:
# > Function F1 - 3 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   2.500000 	 error =  -0.299373 	 relative = 18.93%
# 	 x =   5.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   7.500000 	 error =  +0.124292 	 relative =  4.54%
# 	 x =  10.000000 	 error =  +0.000000 	 relative =  0.00%
#
# > Function F1 - 4 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   1.666667 	 error =  -0.188591 	 relative = 14.61%
# 	 x =   3.333333 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   5.000000 	 error =  +0.045638 	 relative =  2.04%
# 	 x =   6.666667 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   8.333333 	 error =  -0.048469 	 relative =  1.68%
# 	 x =  10.000000 	 error =  +0.000000 	 relative =  0.00%
#
# > Function F1 - 5 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   1.250000 	 error =  -0.135968 	 relative = 12.16%
# 	 x =   2.500000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   3.750000 	 error =  +0.023110 	 relative =  1.19%
# 	 x =   5.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   6.250000 	 error =  -0.014619 	 relative =  0.58%
# 	 x =   7.500000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   8.750000 	 error =  +0.025028 	 relative =  0.85%
# 	 x =  10.000000 	 error =  +0.000000 	 relative =  0.00%
#
# > Function F1 - 8 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   0.714286 	 error =  -0.072243 	 relative =  8.55%
# 	 x =   1.428571 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   2.142857 	 error =  +0.006443 	 relative =  0.44%
# 	 x =   2.857143 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   3.571429 	 error =  -0.001834 	 relative =  0.10%
# 	 x =   4.285714 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   5.000000 	 error =  +0.001040 	 relative =  0.05%
# 	 x =   5.714286 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   6.428571 	 error =  -0.001053 	 relative =  0.04%
# 	 x =   7.142857 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   7.857143 	 error =  +0.001912 	 relative =  0.07%
# 	 x =   8.571429 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   9.285714 	 error =  -0.007052 	 relative =  0.23%
# 	 x =  10.000000 	 error =  +0.000000 	 relative =  0.00%
#
# > Function F2 - 3 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   2.500000 	 error =  -1.249663 	 relative = 208.81%
# 	 x =   5.000000 	 error =  +0.000000 	 relative = -0.00%
# 	 x =   7.500000 	 error =  -1.861201 	 relative = 198.42%
# 	 x =  10.000000 	 error =  +0.000000 	 relative = -0.00%
#
# > Function F2 - 4 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   1.666667 	 error =  -1.324989 	 relative = 133.11%
# 	 x =   3.333333 	 error =  +0.000000 	 relative = -0.00%
# 	 x =   5.000000 	 error =  +1.096191 	 relative = -114.31%
# 	 x =   6.666667 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   8.333333 	 error =  -0.646981 	 relative = 72.92%
# 	 x =  10.000000 	 error =  +0.000000 	 relative = -0.00%
#
# > Function F2 - 5 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   1.250000 	 error =  +0.456444 	 relative = 48.10%
# 	 x =   2.500000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   3.750000 	 error =  +0.018539 	 relative = -3.24%
# 	 x =   5.000000 	 error =  +0.000000 	 relative = -0.00%
# 	 x =   6.250000 	 error =  -0.273637 	 relative = -824.73%
# 	 x =   7.500000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   8.750000 	 error =  +0.907785 	 relative = 145.31%
# 	 x =  10.000000 	 error =  +0.000000 	 relative = -0.00%
#
# > Function F2 - 8 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   0.714286 	 error =  -0.124594 	 relative = 19.02%
# 	 x =   1.428571 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   2.142857 	 error =  +0.031019 	 relative =  3.69%
# 	 x =   2.857143 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   3.571429 	 error =  -0.014507 	 relative = -3.48%
# 	 x =   4.285714 	 error =  +0.000000 	 relative = -0.00%
# 	 x =   5.000000 	 error =  +0.011016 	 relative = -1.15%
# 	 x =   5.714286 	 error =  +0.000000 	 relative = -0.00%
# 	 x =   6.428571 	 error =  -0.013082 	 relative =  9.03%
# 	 x =   7.142857 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   7.857143 	 error =  +0.025121 	 relative =  2.51%
# 	 x =   8.571429 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   9.285714 	 error =  -0.089882 	 relative = 64.84%
# 	 x =  10.000000 	 error =  +0.000000 	 relative = -0.00%
#
# > Function F3 - 3 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   2.500000 	 error = -46.875000 	 relative = 227.27%
# 	 x =   5.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   7.500000 	 error = +46.875000 	 relative = 10.73%
# 	 x =  10.000000 	 error =  +0.000000 	 relative =  0.00%
#
# > Function F3 - 4 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   1.666667 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   3.333333 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   5.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   6.666667 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   8.333333 	 error =  +0.000000 	 relative =  0.00%
# 	 x =  10.000000 	 error =  +0.000000 	 relative =  0.00%
#
# > Function F3 - 5 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   1.250000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   2.500000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   3.750000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   5.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   6.250000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   7.500000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   8.750000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =  10.000000 	 error =  +0.000000 	 relative =  0.00%
#
# > Function F3 - 8 samples
# 	 x =   0.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   0.714286 	 error =  -0.000000 	 relative =  0.00%
# 	 x =   1.428571 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   2.142857 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   2.857143 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   3.571429 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   4.285714 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   5.000000 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   5.714286 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   6.428571 	 error =  -0.000000 	 relative =  0.00%
# 	 x =   7.142857 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   7.857143 	 error =  -0.000000 	 relative =  0.00%
# 	 x =   8.571429 	 error =  +0.000000 	 relative =  0.00%
# 	 x =   9.285714 	 error =  +0.000000 	 relative =  0.00%
# 	 x =  10.000000 	 error =  +0.000000 	 relative =  0.00%
